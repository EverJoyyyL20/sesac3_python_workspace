# %%
# %%writefile my_first_model.py

def my_function():
    print("This is my first module.")
# Out:
# Writing my_first_model.py

# %%
# !type my_first_model.py
# Out:
# def my_function():
#     print("This is my first module.")

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 6C6F-4BFC
#
#  C:\Sesac_Workspace\sesac_python_workspace 디렉터리
#
# 2025-11-17  오후 03:01    <DIR>          .
# 2025-11-04  오후 02:55    <DIR>          ..
# 2025-11-06  오후 02:37             8,281 .gitignore
# 2025-11-17  오후 02:59    <DIR>          .ipynb_checkpoints
# 2025-11-17  오전 11:24    <DIR>          .virtual_documents
# 2025-11-07  오후 01:48    <DIR>          anaconda_projects
# 2025-11-17  오전 10:49            15,932 class_1.ipynb
# 2025-11-17  오전 11:54             5,738 class_2.ipynb
# 2025-11-17  오후 03:01             4,830 module1.ipynb
# 2025-11-17  오후 03:01                61 my_first_model.py
# 2025-11-06  오후 02:37            23,741 python_01.ipynb
# 2025-11-06  오후 02:37            31,460 python_02.ipynb
# 2025-11-06  오후 02:37            21,413 python_03.ipynb
# 2025-11-06  오후 05:28             8,711 python_04.ipynb
# 2025-11-11  오후 05:36            18,942 python_05.ipynb
# 2025-11-13  오후 03:46            35,140 python_06.ipynb
# 2025-11-12  오후 04:32            22,038 python_07.ipynb
# 2025-11-12  오후 02:11            19,611 python_08.ipynb
# 2025-11-13  오후 05:37            25,949 python_09.ipynb
# 2025-11-04  오후 03:46                 0 README.md
#               15개 파일             241,847 바이트
#                5개 디렉터리  895,203,966,976 바이트 남음

# %%
import my_first_model

my_first_model.my_function()
# Out:
# This is my first module.

# %%
# %%writefile my_area.py

PI=3.14
def square_area(a):
    return a**2
def circle_area(r):
    return PI * r **2
# Out:
# Writing my_area.py

# %%
import my_area

print("pi=",my_area.PI)
print("square area=",my_area.square_area(5))
print("circle area=",my_area.circle_area(2))
# Out:
# pi= 3.14
# square area= 25
# circle area= 12.56

# %%
dir(my_area)
# Out:
# ['PI',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'circle_area',
#  'square_area']

# %%
from my_area import PI

print("pi=",PI)
# Out:
# pi= 3.14

# %%
from my_area import square_area
from my_area import circle_area

print("square area=",square_area(5))
print("circle area=",circle_area(2))
# Out:
# square area= 25
# circle area= 12.56

# %%
from my_area import PI,square_area,circle_area

print("pi=",PI)
print("square area=",square_area(5))
print("circle area=",circle_area(2))
# Out:
# pi= 3.14
# square area= 25
# circle area= 12.56

# %%
from my_area import *

print("pi=",PI)
print("sqaure are=",square_area(5))
print("circle area=",circle_area(2))
# Out:
# pi= 3.14
# sqaure are= 25
# circle area= 12.56

# %%
# %%writefile my_module1.py

def func1():
    print("func1 in my_module1")
def func2():
    print("func2 in my_module1")
# Out:
# Writing my_module1.py

# %%
# %%writefile my_module2.py

def func2():
    print("func2 in my_module2")
def func3():
    print("func3 in my_module2")
# Out:
# Writing my_module2.py

# %%
from my_module1 import *
from my_module2 import *

# %%
func1()
func2()
func3()
# Out:
# func1 in my_module1
# func2 in my_module2
# func3 in my_module2

# %%
from my_module2 import *
from my_module1 import *

func1()
func2()
func3()
# Out:
# func1 in my_module1
# func2 in my_module1
# func3 in my_module2

# %%
import my_area as area

print("pi=",area.PI)
print("square area=",area.square_area(5))
print("circle area=",area.circle_area(2))
# Out:
# pi= 3.14
# square area= 25
# circle area= 12.56

# %%
from my_area import PI as pi
from my_area import square_area as square
from my_area import circle_area as circle

print("pi=",pi)
print("square area=",square(5))
print("circle area=",circle(2))
# Out:
# pi= 3.14
# square area= 25
# circle area= 12.56
